# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
import pandas as pd


spark = SparkSession.builder.appName("UserMonthlySpend").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://00ab00e94eb4:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>UserMonthlySpend</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv("large_expenses.csv", header=True, inferSchema=True)

df.show()
# Out:
# +---------+------+----------+------+----------+-----------------+
# |ExpenseID|UserID|CategoryID|Amount|      Date|            Notes|
# +---------+------+----------+------+----------+-----------------+
# |      201|     1|         1| 300.0|2025-06-01| Fruits & Veggies|
# |      202|     1|         3|2200.0|2025-06-02| Electricity Bill|
# |      203|     1|         5| 500.0|2025-06-03|       Food Panda|
# |      204|     1|         2| 200.0|2025-06-04|              Bus|
# |      205|     1|         1| 700.0|2025-06-05|Monthly groceries|
# |      206|     2|         4|5000.0|2025-06-01|           Laptop|
# |      207|     2|         1|1000.0|2025-06-02|          Grocery|
# |      208|     2|         5| 900.0|2025-06-03|      Pizza night|
# |      209|     2|         2| 150.0|2025-06-04|         Rickshaw|
# |      210|     2|         3|1900.0|2025-06-05|       Water Bill|
# |      211|     1|         4|3200.0|2025-06-06|   Shopping Spree|
# |      212|     3|         1| 450.0|2025-06-01|        Mini Mart|
# |      213|     3|         2| 100.0|2025-06-02|       Metro card|
# |      214|     3|         3| 800.0|2025-06-03|    Internet Bill|
# |      215|     3|         4|2200.0|2025-06-04|         Footwear|
# |      216|     3|         5| 600.0|2025-06-05|      Burger King|
# |      217|     1|         1| 900.0|2025-06-06|       Big Basket|
# |      218|     1|         3|2050.0|2025-06-07|         Gas Bill|
# |      219|     1|         5| 450.0|2025-06-08|           Snacks|
# |      220|     1|         2| 170.0|2025-06-09|        Auto fare|
# +---------+------+----------+------+----------+-----------------+
# only showing top 20 rows

# %%
df = df.withColumn("Year", year(col("Date")))
df = df.withColumn("Month", month(col("Date")))

df.show()
# Out:
# +---------+------+----------+------+----------+-----------------+----+-----+
# |ExpenseID|UserID|CategoryID|Amount|      Date|            Notes|Year|Month|
# +---------+------+----------+------+----------+-----------------+----+-----+
# |      201|     1|         1| 300.0|2025-06-01| Fruits & Veggies|2025|    6|
# |      202|     1|         3|2200.0|2025-06-02| Electricity Bill|2025|    6|
# |      203|     1|         5| 500.0|2025-06-03|       Food Panda|2025|    6|
# |      204|     1|         2| 200.0|2025-06-04|              Bus|2025|    6|
# |      205|     1|         1| 700.0|2025-06-05|Monthly groceries|2025|    6|
# |      206|     2|         4|5000.0|2025-06-01|           Laptop|2025|    6|
# |      207|     2|         1|1000.0|2025-06-02|          Grocery|2025|    6|
# |      208|     2|         5| 900.0|2025-06-03|      Pizza night|2025|    6|
# |      209|     2|         2| 150.0|2025-06-04|         Rickshaw|2025|    6|
# |      210|     2|         3|1900.0|2025-06-05|       Water Bill|2025|    6|
# |      211|     1|         4|3200.0|2025-06-06|   Shopping Spree|2025|    6|
# |      212|     3|         1| 450.0|2025-06-01|        Mini Mart|2025|    6|
# |      213|     3|         2| 100.0|2025-06-02|       Metro card|2025|    6|
# |      214|     3|         3| 800.0|2025-06-03|    Internet Bill|2025|    6|
# |      215|     3|         4|2200.0|2025-06-04|         Footwear|2025|    6|
# |      216|     3|         5| 600.0|2025-06-05|      Burger King|2025|    6|
# |      217|     1|         1| 900.0|2025-06-06|       Big Basket|2025|    6|
# |      218|     1|         3|2050.0|2025-06-07|         Gas Bill|2025|    6|
# |      219|     1|         5| 450.0|2025-06-08|           Snacks|2025|    6|
# |      220|     1|         2| 170.0|2025-06-09|        Auto fare|2025|    6|
# +---------+------+----------+------+----------+-----------------+----+-----+
# only showing top 20 rows

# %% [markdown]
# Group by user to calculate total monthly spend

# %%
monthly_spend = df.groupBy("UserID", "Year", "Month") \
                  .agg(_sum("Amount").alias("TotalSpend"))

monthly_spend.show()
df.show()
# Out:
# +------+----+-----+----------+
# |UserID|Year|Month|TotalSpend|
# +------+----+-----+----------+
# |     2|2025|    6|   21360.0|
# |     3|2025|    6|   15670.0|
# |     1|2025|    6|   23900.0|
# +------+----+-----+----------+
#
# +---------+------+----------+------+----------+-----------------+----+-----+
# |ExpenseID|UserID|CategoryID|Amount|      Date|            Notes|Year|Month|
# +---------+------+----------+------+----------+-----------------+----+-----+
# |      201|     1|         1| 300.0|2025-06-01| Fruits & Veggies|2025|    6|
# |      202|     1|         3|2200.0|2025-06-02| Electricity Bill|2025|    6|
# |      203|     1|         5| 500.0|2025-06-03|       Food Panda|2025|    6|
# |      204|     1|         2| 200.0|2025-06-04|              Bus|2025|    6|
# |      205|     1|         1| 700.0|2025-06-05|Monthly groceries|2025|    6|
# |      206|     2|         4|5000.0|2025-06-01|           Laptop|2025|    6|
# |      207|     2|         1|1000.0|2025-06-02|          Grocery|2025|    6|
# |      208|     2|         5| 900.0|2025-06-03|      Pizza night|2025|    6|
# |      209|     2|         2| 150.0|2025-06-04|         Rickshaw|2025|    6|
# |      210|     2|         3|1900.0|2025-06-05|       Water Bill|2025|    6|
# |      211|     1|         4|3200.0|2025-06-06|   Shopping Spree|2025|    6|
# |      212|     3|         1| 450.0|2025-06-01|        Mini Mart|2025|    6|
# |      213|     3|         2| 100.0|2025-06-02|       Metro card|2025|    6|
# |      214|     3|         3| 800.0|2025-06-03|    Internet Bill|2025|    6|
# |      215|     3|         4|2200.0|2025-06-04|         Footwear|2025|    6|
# |      216|     3|         5| 600.0|2025-06-05|      Burger King|2025|    6|
# |      217|     1|         1| 900.0|2025-06-06|       Big Basket|2025|    6|
# |      218|     1|         3|2050.0|2025-06-07|         Gas Bill|2025|    6|
# |      219|     1|         5| 450.0|2025-06-08|           Snacks|2025|    6|
# |      220|     1|         2| 170.0|2025-06-09|        Auto fare|2025|    6|
# +---------+------+----------+------+----------+-----------------+----+-----+
# only showing top 20 rows

# %%
stats = df.groupBy("UserID").agg(avg("Amount").alias("avg_amount"),stddev("Amount").alias("stddev_amount"))

stats.show()
# Out:
# +------+------------------+------------------+
# |UserID|        avg_amount|     stddev_amount|
# +------+------------------+------------------+
# |     1|            1195.0| 1383.993078777948|
# |     3|1044.6666666666667| 920.5810794327265|
# |     2|            1424.0|1242.6975266963168|
# +------+------------------+------------------+

# %%
df = df.join(stats, on="UserID", how="left")

df.show()
# Out:
# +------+---------+----------+------+----------+-----------------+----+-----+------------------+------------------+
# |UserID|ExpenseID|CategoryID|Amount|      Date|            Notes|Year|Month|        avg_amount|     stddev_amount|
# +------+---------+----------+------+----------+-----------------+----+-----+------------------+------------------+
# |     1|      201|         1| 300.0|2025-06-01| Fruits & Veggies|2025|    6|            1195.0| 1383.993078777948|
# |     1|      202|         3|2200.0|2025-06-02| Electricity Bill|2025|    6|            1195.0| 1383.993078777948|
# |     1|      203|         5| 500.0|2025-06-03|       Food Panda|2025|    6|            1195.0| 1383.993078777948|
# |     1|      204|         2| 200.0|2025-06-04|              Bus|2025|    6|            1195.0| 1383.993078777948|
# |     1|      205|         1| 700.0|2025-06-05|Monthly groceries|2025|    6|            1195.0| 1383.993078777948|
# |     2|      206|         4|5000.0|2025-06-01|           Laptop|2025|    6|            1424.0|1242.6975266963168|
# |     2|      207|         1|1000.0|2025-06-02|          Grocery|2025|    6|            1424.0|1242.6975266963168|
# |     2|      208|         5| 900.0|2025-06-03|      Pizza night|2025|    6|            1424.0|1242.6975266963168|
# |     2|      209|         2| 150.0|2025-06-04|         Rickshaw|2025|    6|            1424.0|1242.6975266963168|
# |     2|      210|         3|1900.0|2025-06-05|       Water Bill|2025|    6|            1424.0|1242.6975266963168|
# |     1|      211|         4|3200.0|2025-06-06|   Shopping Spree|2025|    6|            1195.0| 1383.993078777948|
# |     3|      212|         1| 450.0|2025-06-01|        Mini Mart|2025|    6|1044.6666666666667| 920.5810794327265|
# |     3|      213|         2| 100.0|2025-06-02|       Metro card|2025|    6|1044.6666666666667| 920.5810794327265|
# |     3|      214|         3| 800.0|2025-06-03|    Internet Bill|2025|    6|1044.6666666666667| 920.5810794327265|
# |     3|      215|         4|2200.0|2025-06-04|         Footwear|2025|    6|1044.6666666666667| 920.5810794327265|
# |     3|      216|         5| 600.0|2025-06-05|      Burger King|2025|    6|1044.6666666666667| 920.5810794327265|
# |     1|      217|         1| 900.0|2025-06-06|       Big Basket|2025|    6|            1195.0| 1383.993078777948|
# |     1|      218|         3|2050.0|2025-06-07|         Gas Bill|2025|    6|            1195.0| 1383.993078777948|
# |     1|      219|         5| 450.0|2025-06-08|           Snacks|2025|    6|            1195.0| 1383.993078777948|
# |     1|      220|         2| 170.0|2025-06-09|        Auto fare|2025|    6|            1195.0| 1383.993078777948|
# +------+---------+----------+------+----------+-----------------+----+-----+------------------+------------------+
# only showing top 20 rows

# %%
df_anomalies = df.withColumn("is_anomaly", col("Amount") > col("avg_amount") + 2 * col("stddev_amount"))

df_anomalies.show()
# Out:
# +------+---------+----------+------+----------+-----------------+----+-----+------------------+------------------+----------+
# |UserID|ExpenseID|CategoryID|Amount|      Date|            Notes|Year|Month|        avg_amount|     stddev_amount|is_anomaly|
# +------+---------+----------+------+----------+-----------------+----+-----+------------------+------------------+----------+
# |     1|      201|         1| 300.0|2025-06-01| Fruits & Veggies|2025|    6|            1195.0| 1383.993078777948|     false|
# |     1|      202|         3|2200.0|2025-06-02| Electricity Bill|2025|    6|            1195.0| 1383.993078777948|     false|
# |     1|      203|         5| 500.0|2025-06-03|       Food Panda|2025|    6|            1195.0| 1383.993078777948|     false|
# |     1|      204|         2| 200.0|2025-06-04|              Bus|2025|    6|            1195.0| 1383.993078777948|     false|
# |     1|      205|         1| 700.0|2025-06-05|Monthly groceries|2025|    6|            1195.0| 1383.993078777948|     false|
# |     2|      206|         4|5000.0|2025-06-01|           Laptop|2025|    6|            1424.0|1242.6975266963168|      true|
# |     2|      207|         1|1000.0|2025-06-02|          Grocery|2025|    6|            1424.0|1242.6975266963168|     false|
# |     2|      208|         5| 900.0|2025-06-03|      Pizza night|2025|    6|            1424.0|1242.6975266963168|     false|
# |     2|      209|         2| 150.0|2025-06-04|         Rickshaw|2025|    6|            1424.0|1242.6975266963168|     false|
# |     2|      210|         3|1900.0|2025-06-05|       Water Bill|2025|    6|            1424.0|1242.6975266963168|     false|
# |     1|      211|         4|3200.0|2025-06-06|   Shopping Spree|2025|    6|            1195.0| 1383.993078777948|     false|
# |     3|      212|         1| 450.0|2025-06-01|        Mini Mart|2025|    6|1044.6666666666667| 920.5810794327265|     false|
# |     3|      213|         2| 100.0|2025-06-02|       Metro card|2025|    6|1044.6666666666667| 920.5810794327265|     false|
# |     3|      214|         3| 800.0|2025-06-03|    Internet Bill|2025|    6|1044.6666666666667| 920.5810794327265|     false|
# |     3|      215|         4|2200.0|2025-06-04|         Footwear|2025|    6|1044.6666666666667| 920.5810794327265|     false|
# |     3|      216|         5| 600.0|2025-06-05|      Burger King|2025|    6|1044.6666666666667| 920.5810794327265|     false|
# |     1|      217|         1| 900.0|2025-06-06|       Big Basket|2025|    6|            1195.0| 1383.993078777948|     false|
# |     1|      218|         3|2050.0|2025-06-07|         Gas Bill|2025|    6|            1195.0| 1383.993078777948|     false|
# |     1|      219|         5| 450.0|2025-06-08|           Snacks|2025|    6|            1195.0| 1383.993078777948|     false|
# |     1|      220|         2| 170.0|2025-06-09|        Auto fare|2025|    6|            1195.0| 1383.993078777948|     false|
# +------+---------+----------+------+----------+-----------------+----+-----+------------------+------------------+----------+
# only showing top 20 rows

# %% [markdown]
# Detect unusual spikes or large one-time expenses

# %%
anomalies = df_anomalies.filter(col("is_anomaly") == True)

anomalies.select("ExpenseID", "UserID", "Amount", "avg_amount", "stddev_amount").show()
# Out:
# +---------+------+------+----------+------------------+
# |ExpenseID|UserID|Amount|avg_amount|     stddev_amount|
# +---------+------+------+----------+------------------+
# |      247|     1|5000.0|    1195.0| 1383.993078777948|
# |      232|     1|4000.0|    1195.0| 1383.993078777948|
# |      206|     2|5000.0|    1424.0|1242.6975266963168|
# +---------+------+------+----------+------------------+

# %%
anomalies.select("ExpenseID", "UserID", "Amount", "avg_amount", "stddev_amount").toPandas().to_csv("anomalies.csv")
