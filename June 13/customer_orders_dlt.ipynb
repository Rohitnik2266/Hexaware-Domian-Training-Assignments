# %%
import dlt
from pyspark.sql.functions import col, expr, count, avg, desc

#1: Load customers.csv
@dlt.table(name="customers_raw")
def load_customers():
    return (
        spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/azuser3559_mml.local@techademy.com/customers.csv")
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>customers_raw</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>CustomerID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>City</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Age</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2342854597430550#joblist/pipelines/create?initialSource=%2FUsers%2Fazuser3559_mml.local%40techademy.com%2Fcustomer_orders_dlt&redirectNotebookId=2053208660251334">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
#2: Load orders.csv
@dlt.table(name="orders_raw")
def load_orders():
    return (
        spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/azuser3559_mml.local@techademy.com/orders.csv")
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>orders_raw</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>OrderID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>CustomerID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Product</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderDate</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2342854597430550#joblist/pipelines/create?initialSource=%2FUsers%2Fazuser3559_mml.local%40techademy.com%2Fcustomer_orders_dlt&redirectNotebookId=2053208660251334">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
#3: Transform orders with TotalAmount
@dlt.table(name="orders_with_amount")
def add_total_amount():
    df = dlt.read("orders_raw")
    return df.withColumn("TotalAmount", col("Quantity") * col("Price"))
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>orders_with_amount</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>OrderID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>CustomerID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Product</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>TotalAmount</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2342854597430550#joblist/pipelines/create?initialSource=%2FUsers%2Fazuser3559_mml.local%40techademy.com%2Fcustomer_orders_dlt&redirectNotebookId=2053208660251334">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
#4: Join customers and orders
@dlt.table(name="customer_orders")
def join_customers_orders():
    customers_df = dlt.read("customers_raw")
    orders_df = dlt.read("orders_with_amount")
    return customers_df.join(orders_df, on="CustomerID", how="inner")
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>customer_orders</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>CustomerID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>City</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Age</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Product</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>TotalAmount</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2342854597430550#joblist/pipelines/create?initialSource=%2FUsers%2Fazuser3559_mml.local%40techademy.com%2Fcustomer_orders_dlt&redirectNotebookId=2053208660251334">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
#5: Filter orders with TotalAmount > 20000
@dlt.table(name="high_value_orders")
def filter_high_value_orders():
    df = dlt.read("customer_orders")
    return df.filter(col("TotalAmount") > 20000)
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>high_value_orders</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>CustomerID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>City</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Age</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Product</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>TotalAmount</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2342854597430550#joblist/pipelines/create?initialSource=%2FUsers%2Fazuser3559_mml.local%40techademy.com%2Fcustomer_orders_dlt&redirectNotebookId=2053208660251334">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
#6: Customers who placed more than 1 order
@dlt.table(name="multiple_orders")
def multiple_orders():
    df = dlt.read("customer_orders")
    return (
        df.groupBy("CustomerID", "Name")
        .agg(count("OrderID").alias("OrderCount"))
        .filter(col("OrderCount") > 1)
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>multiple_orders</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>CustomerID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderCount</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2342854597430550#joblist/pipelines/create?initialSource=%2FUsers%2Fazuser3559_mml.local%40techademy.com%2Fcustomer_orders_dlt&redirectNotebookId=2053208660251334">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
#7: Average order value by city
@dlt.table(name="avg_order_by_city")
def avg_order_by_city():
    df = dlt.read("customer_orders")
    return (
        df.groupBy("City")
        .agg(avg("TotalAmount").alias("AvgOrderValue"))
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>avg_order_by_city</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>City</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>AvgOrderValue</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2342854597430550#joblist/pipelines/create?initialSource=%2FUsers%2Fazuser3559_mml.local%40techademy.com%2Fcustomer_orders_dlt&redirectNotebookId=2053208660251334">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
#8: Sorted orders by OrderDate descending
@dlt.table(name="orders_sorted_desc")
def orders_sorted():
    df = dlt.read("customer_orders")
    return df.orderBy(desc("OrderDate"))
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>orders_sorted_desc</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>CustomerID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>City</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Age</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Product</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>TotalAmount</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2342854597430550#joblist/pipelines/create?initialSource=%2FUsers%2Fazuser3559_mml.local%40techademy.com%2Fcustomer_orders_dlt&redirectNotebookId=2053208660251334">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
#9: Write result as partitioned Parquet by City
@dlt.table(name="partitioned_orders")
def write_parquet_partitioned():
    df = dlt.read("customer_orders")
    return df.repartition("City")  # DLT handles Parquet automatically
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>partitioned_orders</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>CustomerID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>City</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Age</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Product</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderDate</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>TotalAmount</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=2342854597430550#joblist/pipelines/create?initialSource=%2FUsers%2Fazuser3559_mml.local%40techademy.com%2Fcustomer_orders_dlt&redirectNotebookId=2053208660251334">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>
